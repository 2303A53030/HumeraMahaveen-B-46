# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A53030/HumeraMahaveen-B-46/blob/main/2303A53030_LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
list1=[1,2,3]
array1 = np.array(list1)
array1
# Out:
# array([1, 2, 3])

# %%
type(list1)
type(array1)
list2=[3,2,1]
array2 = np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1 : ", array1 * array2)
print("array2 divided by array1 :",array2/array1)
print("array2 raised to the power of array1 :",array2 ** array1)
print(f"{array2} raised to the power of {array1} :,{array2 ** array1}")
# Out:
# array2 multiplied by array1 :  [3 4 3]
# array2 divided by array1 : [3.         1.         0.33333333]
# array2 raised to the power of array1 : [3 4 1]
# [3 2 1] raised to the power of [1 2 3] :,[3 4 1]

# %%
#sine function
print("Sine :",np.sin(array1))
#logarithm
print("Natural logarithm :",np.log(array1))
print("Base-10 logarithm :",np.log10(array1))
print("Base-2 logarithm : ",np.log2(array1))
#exponential
print("Exponential :",np.exp(array1))
# Out:
# Sine : [0.84147098 0.90929743 0.14112001]
# Natural logarithm : [0.         0.69314718 1.09861229]
# Base-10 logarithm : [0.         0.30103    0.47712125]
# Base-2 logarithm :  [0.        1.        1.5849625]
# Exponential : [ 2.71828183  7.3890561  20.08553692]

# %%
print("Adding two numpy arrays {array1} and {array2} together :",array1+array2)
print(f"Adding two numpy arrays {array1} and {array2} together :{array1+array2}")
# Out:
# Adding two numpy arrays {array1} and {array2} together : [4 4 4]
# Adding two numpy arrays [1 2 3] and [3 2 1] together :[4 4 4]

# %%
people = ['Ann','Brandon','Chen','David','Emily','Farook','Gagan','Hamish','Imran','Julio','Katherine','Lily']
age=[21,12,32,45,37,18,28,52,5,40,48,15]
weight=[55,35,77,68,70,60,72,69,18,65,82,48]
height=[160,135,170,165,173,168,175,159,105,171,155,158]
import matplotlib.pyplot as plt
#creating static animated and interactive visualitization
plt.scatter(weight,height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()
#Bar Graph(Length,breadth,title)
plt.figure(figsize = (12,4))
plt.title("People's weight in kgs",fontsize = 16,fontstyle='italic')
#main plot funcction 'bar'
plt.bar(x=people,height=weight,width=0.6,color='green',edgecolor='k',alpha=0.6)
#edgecolor='k' sets the edgecolor of the bars with 1 beign fully opaque and 0 fully transparent
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize = 15, rotation = 30)
plt.yticks(fontsize=15)
plt.ylabel("Weight(in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))
#main plot function 'Hist'
plt.hist(weight,color='pink',edgecolor='k',alpha=0.75,bins=5)
#bins=5:The number bins (interval) to divide the data range
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight(in kgs)",fontsize=15)
#plt.xticks(fontsize=15)
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df1 = pd.read_table("/content/drive/MyDrive/pp.txt")

# %%
df1
# Out:
#   First line: This is a test file
# 0             This is second line
# 1                      third line
# 2          and subsiquent lines..
# 3                      and more..

# %%
data2 = pd.read_csv("/content/drive/MyDrive/Spd.csv")

# %%
data2
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
data3 = pd.read_excel("/content/drive/MyDrive/Historicalinvesttemp.xlsx")

# %%
data3
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN                               NaN        NaN        NaN
# 1         NaN                               NaN        NaN        NaN
# 2         NaN                               NaN        NaN        NaN
# 3         NaN                               NaN        NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN        NaN
# ..        ...                               ...        ...        ...
# 85       2007                            0.0549     0.0988     0.0466
# 86       2008                             -0.37     0.2587      0.016
# 87       2009                            0.2646     -0.149      0.001
# 88        NaN                            stocks     tbills      bonds
# 89   averages                               NaN        NaN        NaN
#
# [90 rows x 4 columns]

# %%
import numpy as np
from queue import Queue

# %%
graph ={
    0: [1,2,3],
    1: [0,2],
    2: [0,1,3,5],
    3: [0,2,4],
    4: [3,5,7],
    5: [4,6,7],
    6: [5,7],
    7: [4,5,6],
    8:[]
}
print("The adjacency List representing the graph is :")
print(graph) # print the adjacency list to share the graph's structure
# Out:
# The adjacency List representing the graph is :
# {0: [1, 2, 3], 1: [0, 2], 2: [0, 1, 3, 5], 3: [0, 2, 4], 4: [3, 5, 7], 5: [4, 6, 7], 6: [5, 7], 7: [4, 5, 6], 8: []}

# %%
#Define BFS function
def bfs(graph,source):
  Q = Queue()
  visited_vertices = set()
  Q.put(source)
  visited_vertices.add(source)

  while not Q.empty():
    vertex = Q.get()
    print(vertex, end="--")

    for u in graph[vertex]:
      if u not in visited_vertices:
        Q.put(u)
        visited_vertices.add(u)

print("BFS traversal of graph with source 0 is:")
bfs(graph,0)
# Out:
# BFS traversal of graph with source 0 is:
# 0--1--2--3--5--4--6--7--
